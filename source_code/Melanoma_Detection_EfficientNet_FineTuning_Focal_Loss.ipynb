# %%
# ============================================
#
# EfficientNetB0 + Fine-tuning + Focal Loss
# ISIC 2017 binary classification
# ============================================

from google.colab import drive
drive.mount('/content/drive')

# ============================================
# 1. IMPORTS
# ============================================
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    average_precision_score,
    f1_score,
    precision_score,
    recall_score
)

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import backend as K

# ============================================
# 2. REPRODUCIBILITY
# ============================================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ============================================
# 3. PATHS
# ============================================
train_dir = "/content/drive/MyDrive/training"
val_dir   = "/content/drive/MyDrive/validation"

train_csv = "/content/drive/MyDrive/ISIC-2017_Training_Part3_GroundTruth.csv"
val_csv   = "/content/drive/MyDrive/ISIC-2017_Validation_Part3_GroundTruth.csv"

output_dir = "/content/drive/MyDrive/isic_efficientnet_improved_output"
os.makedirs(output_dir, exist_ok=True)

print("Train folder exists:", os.path.exists(train_dir))
print("Val folder exists:", os.path.exists(val_dir))
print("Train CSV exists:", os.path.exists(train_csv))
print("Val CSV exists:", os.path.exists(val_csv))

# ============================================
# 4. LOAD CSV
# ============================================
train_df = pd.read_csv(train_csv)
val_df = pd.read_csv(val_csv)

print("Training CSV columns:", train_df.columns.tolist())
print("Validation CSV columns:", val_df.columns.tolist())

# create filename + filepath
train_df["filename"] = train_df["image_id"].astype(str) + ".jpg"
val_df["filename"] = val_df["image_id"].astype(str) + ".jpg"

train_df["filepath"] = train_df["filename"].apply(lambda x: os.path.join(train_dir, x))
val_df["filepath"] = val_df["filename"].apply(lambda x: os.path.join(val_dir, x))

# binary label
train_df["label"] = train_df["melanoma"].astype(int)
val_df["label"] = val_df["melanoma"].astype(int)

# keep existing files only
train_df = train_df[train_df["filepath"].apply(os.path.exists)].reset_index(drop=True)
val_df = val_df[val_df["filepath"].apply(os.path.exists)].reset_index(drop=True)

print("Training images found:", len(train_df))
print("Validation images found:", len(val_df))

print("\nTraining label distribution:")
print(train_df["label"].value_counts())

print("\nValidation label distribution:")
print(val_df["label"].value_counts())

# ============================================
# 5. CLASS WEIGHTS
# ============================================
class_weights_array = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_df["label"]),
    y=train_df["label"]
)
class_weights = dict(enumerate(class_weights_array))
print("\nClass weights:", class_weights)

# ============================================
# 6. CONFIG
# ============================================
IMG_SIZE = 300
BATCH_SIZE = 16
EPOCHS_STAGE1 = 10
EPOCHS_STAGE2 = 20
AUTOTUNE = tf.data.AUTOTUNE

# ============================================
# 7. FOCAL LOSS
# ============================================
def focal_loss(alpha=0.75, gamma=2.0):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        bce = K.binary_crossentropy(y_true, y_pred)
        pt = tf.exp(-bce)
        focal = alpha * K.pow((1 - pt), gamma) * bce
        return K.mean(focal)
    return loss

# ============================================
# 8. IMAGE LOADING + AUGMENTATION
# ============================================
def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)
    img = preprocess_input(img)
    label = tf.cast(label, tf.float32)
    return img, label

def augment_image(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, max_delta=0.15)
    img = tf.image.random_contrast(img, lower=0.85, upper=1.15)
    return img, label

# ============================================
# 9. DATASET BUILDING
# ============================================
train_ds = tf.data.Dataset.from_tensor_slices(
    (train_df["filepath"].values, train_df["label"].values)
)

val_ds = tf.data.Dataset.from_tensor_slices(
    (val_df["filepath"].values, val_df["label"].values)
)

train_ds = (
    train_ds
    .shuffle(buffer_size=len(train_df), reshuffle_each_iteration=True)
    .map(load_image, num_parallel_calls=AUTOTUNE)
    .map(augment_image, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val_ds = (
    val_ds
    .map(load_image, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# ============================================
# 10. DISPLAY SAMPLE IMAGES
# ============================================
def load_image_for_display(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.uint8)
    return img

plt.figure(figsize=(12, 8))
sample_n = min(6, len(train_df))
for i in range(sample_n):
    img = load_image_for_display(train_df["filepath"].iloc[i])
    label = train_df["label"].iloc[i]
    ax = plt.subplot(2, 3, i + 1)
    plt.imshow(img.numpy())
    plt.title(f"Label: {label}")
    plt.axis("off")
plt.tight_layout()
plt.show()

# ============================================
# 11. BUILD MODEL
# ============================================
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Stage 1: freeze backbone
base_model.trainable = False

inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(128, activation="relu")(x)
x = tf.keras.layers.Dropout(0.3)(x)
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)

model = tf.keras.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=focal_loss(alpha=0.75, gamma=2.0),
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

model.summary()

# ============================================
# 12. CALLBACKS
# ============================================
stage1_model_path = os.path.join(output_dir, "best_stage1.keras")
stage2_model_path = os.path.join(output_dir, "best_stage2.keras")

callbacks_stage1 = [
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=stage1_model_path,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-7,
        verbose=1
    )
]

# ============================================
# 13. TRAIN STAGE 1
# ============================================
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE1,
    class_weight=class_weights,
    callbacks=callbacks_stage1
)

# ============================================
# 14. FINE-TUNING STAGE 2
# ============================================
base_model.trainable = True

# Freeze earlier layers, unfreeze later layers
for layer in base_model.layers[:-30]:
    layer.trainable = False
for layer in base_model.layers[-30:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=focal_loss(alpha=0.75, gamma=2.0),
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

callbacks_stage2 = [
    EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=stage2_model_path,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    )
]

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE2,
    class_weight=class_weights,
    callbacks=callbacks_stage2
)

# ============================================
# 15. SAVE FINAL MODEL
# ============================================
final_model_path = os.path.join(output_dir, "final_efficientnet_improved.keras")
model.save(final_model_path)
print("Final model saved to:", final_model_path)

# ============================================
# 16. MERGE TRAINING HISTORY
# ============================================
def merge_histories(h1, h2):
    merged = {}
    for key in h1.history.keys():
        merged[key] = h1.history[key] + h2.history[key]
    return merged

history = merge_histories(history1, history2)

# ============================================
# 17. PLOT TRAINING CURVES
# ============================================
def plot_history(metric, ylabel, filename):
    plt.figure(figsize=(8, 6))
    plt.plot(history[metric], label=f"train_{metric}")
    plt.plot(history[f"val_{metric}"], label=f"val_{metric}")
    plt.title(metric.upper())
    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(output_dir, filename), dpi=300, bbox_inches="tight")
    plt.show()

plot_history("accuracy", "Accuracy", "accuracy.png")
plot_history("loss", "Loss", "loss.png")
plot_history("auc", "AUC", "auc.png")
plot_history("precision", "Precision", "precision.png")
plot_history("recall", "Recall", "recall.png")

# ============================================
# 18. PREDICTIONS ON VALIDATION SET
# ============================================
y_true = val_df["label"].values
y_pred_prob = model.predict(val_ds).ravel()

print("Min probability:", y_pred_prob.min())
print("Max probability:", y_pred_prob.max())
print("Mean probability:", y_pred_prob.mean())

# ============================================
# 19. THRESHOLD TUNING USING F1
# ============================================
thresholds_to_test = np.arange(0.10, 0.91, 0.05)

best_threshold = 0.5
best_f1 = 0.0
best_precision = 0.0
best_recall = 0.0

results = []

for th in thresholds_to_test:
    y_pred_temp = (y_pred_prob >= th).astype(int)
    f1 = f1_score(y_true, y_pred_temp, zero_division=0)
    prec = precision_score(y_true, y_pred_temp, zero_division=0)
    rec = recall_score(y_true, y_pred_temp, zero_division=0)
    results.append([th, prec, rec, f1])

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th
        best_precision = prec
        best_recall = rec

threshold_df = pd.DataFrame(results, columns=["Threshold", "Precision", "Recall", "F1"])
threshold_df.to_csv(os.path.join(output_dir, "threshold_tuning.csv"), index=False)

print("\nThreshold tuning results:")
print(threshold_df)

print("\nBest threshold based on F1:")
print("Threshold :", best_threshold)
print("Precision :", best_precision)
print("Recall    :", best_recall)
print("F1-score  :", best_f1)

# final prediction using best threshold
y_pred = (y_pred_prob >= best_threshold).astype(int)

# ============================================
# 20. CONFUSION MATRIX + CLASSIFICATION REPORT
# ============================================
cm = confusion_matrix(y_true, y_pred)
print("\nConfusion Matrix:")
print(cm)

print("\nClassification Report:")
print(classification_report(
    y_true,
    y_pred,
    target_names=["Non-Melanoma", "Melanoma"],
    digits=4
))

plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix (Threshold={best_threshold:.2f})")
plt.colorbar()

tick_marks = np.arange(2)
plt.xticks(tick_marks, ["Non-Melanoma", "Melanoma"])
plt.yticks(tick_marks, ["Non-Melanoma", "Melanoma"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], "d"), ha="center", va="center", color="black")

plt.tight_layout()
plt.savefig(os.path.join(output_dir, "confusion_matrix.png"), dpi=300, bbox_inches="tight")
plt.show()

# ============================================
# 21. ROC CURVE
# ============================================
fpr, tpr, roc_thresholds = roc_curve(y_true, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(7, 6))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig(os.path.join(output_dir, "roc_curve.png"), dpi=300, bbox_inches="tight")
plt.show()

print("Validation ROC AUC:", roc_auc)

# ============================================
# 22. PRECISION-RECALL CURVE
# ============================================
precision_vals, recall_vals, pr_thresholds = precision_recall_curve(y_true, y_pred_prob)
ap_score = average_precision_score(y_true, y_pred_prob)

plt.figure(figsize=(7, 6))
plt.plot(recall_vals, precision_vals, label=f"PR curve (AP = {ap_score:.4f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend(loc="lower left")
plt.grid(True)
plt.savefig(os.path.join(output_dir, "pr_curve.png"), dpi=300, bbox_inches="tight")
plt.show()

print("Average Precision (AP):", ap_score)

# ============================================
# 23. SAVE FINAL METRICS TO TXT
# ============================================
report_text = classification_report(
    y_true,
    y_pred,
    target_names=["Non-Melanoma", "Melanoma"],
    digits=4
)

with open(os.path.join(output_dir, "final_metrics.txt"), "w") as f:
    f.write(f"Best Threshold: {best_threshold:.4f}\n")
    f.write(f"ROC AUC: {roc_auc:.4f}\n")
    f.write(f"Average Precision: {ap_score:.4f}\n\n")
    f.write("Confusion Matrix:\n")
    f.write(str(cm))
    f.write("\n\nClassification Report:\n")
    f.write(report_text)

print("\nAll outputs saved in:", output_dir)
# Out:
# Mounted at /content/drive
# Train folder exists: True
# Val folder exists: True
# Train CSV exists: True
# Val CSV exists: True
# Training CSV columns: ['image_id', 'melanoma', 'seborrheic_keratosis']
# Validation CSV columns: ['image_id', 'melanoma', 'seborrheic_keratosis']
# Training images found: 2000
# Validation images found: 150
#
# Training label distribution:
# label
# 0    1626
# 1     374
# Name: count, dtype: int64
#
# Validation label distribution:
# label
# 0    120
# 1     30
# Name: count, dtype: int64
#
# Class weights: {0: np.float64(0.6150061500615006), 1: np.float64(2.6737967914438503)}
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 300, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 10, 10, 1280)   │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,218,788 (16.09 MB)
#  Trainable params: 166,657 (651.00 KB)
#  Non-trainable params: 4,052,131 (15.46 MB)
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6784 - auc: 0.5598 - loss: 0.2773 - precision: 0.2208 - recall: 0.3262
# Epoch 1: val_loss improved from None to 0.10204, saving model to /content/drive/MyDrive/isic_efficientnet_improved_output/best_stage1.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/isic_efficientnet_improved_output/best_stage1.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 728s 6s/step - accuracy: 0.6860 - auc: 0.5909 - loss: 0.2633 - precision: 0.2440 - recall: 0.3235 - val_accuracy: 0.7133 - val_auc: 0.6915 - val_loss: 0.1020 - val_precision: 0.3415 - val_recall: 0.4667 - learning_rate: 1.0000e-04
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7224 - auc: 0.6562 - loss: 0.2240 - precision: 0.2971 - recall: 0.3729
# Epoch 2: val_loss did not improve from 0.10204
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 428s 3s/step - accuracy: 0.7245 - auc: 0.6507 - loss: 0.2245 - precision: 0.3046 - recall: 0.3690 - val_accuracy: 0.7800 - val_auc: 0.6824 - val_loss: 0.1083 - val_precision: 0.4286 - val_recall: 0.3000 - learning_rate: 1.0000e-04
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7149 - auc: 0.6388 - loss: 0.2332 - precision: 0.3140 - recall: 0.3353
# Epoch 3: val_loss did not improve from 0.10204
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 455s 4s/step - accuracy: 0.7245 - auc: 0.6593 - loss: 0.2067 - precision: 0.2956 - recall: 0.3422 - val_accuracy: 0.7400 - val_auc: 0.6664 - val_loss: 0.1305 - val_precision: 0.3333 - val_recall: 0.3000 - learning_rate: 1.0000e-04
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7233 - auc: 0.6401 - loss: 0.2382 - precision: 0.3120 - recall: 0.3455
# Epoch 4: val_loss did not improve from 0.10204
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 442s 4s/step - accuracy: 0.7320 - auc: 0.6599 - loss: 0.2142 - precision: 0.3116 - recall: 0.3583 - val_accuracy: 0.7800 - val_auc: 0.6833 - val_loss: 0.1410 - val_precision: 0.4211 - val_recall: 0.2667 - learning_rate: 5.0000e-05
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7623 - auc: 0.6745 - loss: 0.1813 - precision: 0.3459 - recall: 0.4074
# Epoch 5: val_loss did not improve from 0.10204
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 430s 3s/step - accuracy: 0.7475 - auc: 0.6850 - loss: 0.1884 - precision: 0.3466 - recall: 0.3957 - val_accuracy: 0.7733 - val_auc: 0.7011 - val_loss: 0.1369 - val_precision: 0.4091 - val_recall: 0.3000 - learning_rate: 5.0000e-05
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7545 - auc: 0.7078 - loss: 0.1795 - precision: 0.3627 - recall: 0.4118
# Epoch 6: val_loss did not improve from 0.10204
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 438s 3s/step - accuracy: 0.7500 - auc: 0.6961 - loss: 0.1815 - precision: 0.3514 - recall: 0.3984 - val_accuracy: 0.7867 - val_auc: 0.7151 - val_loss: 0.1387 - val_precision: 0.4545 - val_recall: 0.3333 - learning_rate: 2.5000e-05
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6937 - auc: 0.5720 - loss: 0.2861 - precision: 0.2243 - recall: 0.2734
# Epoch 1: val_loss improved from None to 0.09614, saving model to /content/drive/MyDrive/isic_efficientnet_improved_output/best_stage2.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/isic_efficientnet_improved_output/best_stage2.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 521s 4s/step - accuracy: 0.7040 - auc: 0.5932 - loss: 0.2729 - precision: 0.2630 - recall: 0.3235 - val_accuracy: 0.7467 - val_auc: 0.7447 - val_loss: 0.0961 - val_precision: 0.3333 - val_recall: 0.2667 - learning_rate: 1.0000e-05
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6927 - auc: 0.5997 - loss: 0.2509 - precision: 0.2627 - recall: 0.3425
# Epoch 2: val_loss did not improve from 0.09614
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 505s 4s/step - accuracy: 0.6965 - auc: 0.5944 - loss: 0.2586 - precision: 0.2608 - recall: 0.3396 - val_accuracy: 0.7733 - val_auc: 0.7521 - val_loss: 0.1112 - val_precision: 0.3571 - val_recall: 0.1667 - learning_rate: 1.0000e-05
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6838 - auc: 0.5654 - loss: 0.2820 - precision: 0.2305 - recall: 0.3235
# Epoch 3: val_loss did not improve from 0.09614
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 508s 4s/step - accuracy: 0.6975 - auc: 0.5982 - loss: 0.2709 - precision: 0.2638 - recall: 0.3449 - val_accuracy: 0.7800 - val_auc: 0.7524 - val_loss: 0.1255 - val_precision: 0.4000 - val_recall: 0.2000 - learning_rate: 1.0000e-05
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7107 - auc: 0.6269 - loss: 0.2389 - precision: 0.2809 - recall: 0.3185
# Epoch 4: val_loss did not improve from 0.09614
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 481s 4s/step - accuracy: 0.7160 - auc: 0.6350 - loss: 0.2274 - precision: 0.2835 - recall: 0.3396 - val_accuracy: 0.7933 - val_auc: 0.7651 - val_loss: 0.1266 - val_precision: 0.4615 - val_recall: 0.2000 - learning_rate: 1.0000e-05
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6991 - auc: 0.6440 - loss: 0.2324 - precision: 0.2763 - recall: 0.3770
# Epoch 5: val_loss did not improve from 0.09614
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 502s 4s/step - accuracy: 0.7150 - auc: 0.6370 - loss: 0.2437 - precision: 0.2950 - recall: 0.3770 - val_accuracy: 0.7933 - val_auc: 0.7665 - val_loss: 0.1269 - val_precision: 0.4615 - val_recall: 0.2000 - learning_rate: 5.0000e-06
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7126 - auc: 0.6057 - loss: 0.2539 - precision: 0.2697 - recall: 0.3039
# Epoch 6: val_loss did not improve from 0.09614
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 496s 4s/step - accuracy: 0.7125 - auc: 0.6350 - loss: 0.2383 - precision: 0.2820 - recall: 0.3476 - val_accuracy: 0.7933 - val_auc: 0.7644 - val_loss: 0.1298 - val_precision: 0.4615 - val_recall: 0.2000 - learning_rate: 5.0000e-06
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7135 - auc: 0.6372 - loss: 0.2255 - precision: 0.2651 - recall: 0.3748
# Epoch 7: val_loss did not improve from 0.09614
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 504s 4s/step - accuracy: 0.7155 - auc: 0.6485 - loss: 0.2404 - precision: 0.2973 - recall: 0.3824 - val_accuracy: 0.7867 - val_auc: 0.7690 - val_loss: 0.1283 - val_precision: 0.4286 - val_recall: 0.2000 - learning_rate: 5.0000e-06
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7242 - auc: 0.6581 - loss: 0.2277 - precision: 0.3105 - recall: 0.3716
# Epoch 8: val_loss did not improve from 0.09614
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 495s 4s/step - accuracy: 0.7260 - auc: 0.6734 - loss: 0.2249 - precision: 0.3165 - recall: 0.4011 - val_accuracy: 0.7933 - val_auc: 0.7718 - val_loss: 0.1281 - val_precision: 0.4615 - val_recall: 0.2000 - learning_rate: 2.5000e-06
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7329 - auc: 0.6470 - loss: 0.2208 - precision: 0.3165 - recall: 0.3531
# Epoch 9: val_loss did not improve from 0.09614
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 534s 4s/step - accuracy: 0.7275 - auc: 0.6495 - loss: 0.2268 - precision: 0.3121 - recall: 0.3797 - val_accuracy: 0.8000 - val_auc: 0.7728 - val_loss: 0.1277 - val_precision: 0.5000 - val_recall: 0.2333 - learning_rate: 2.5000e-06
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Final model saved to: /content/drive/MyDrive/isic_efficientnet_improved_output/final_efficientnet_improved.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step
# Min probability: 0.022850119
# Max probability: 0.7410905
# Mean probability: 0.3173815
#
# Threshold tuning results:
#     Threshold  Precision    Recall        F1
# 0        0.10   0.225564  1.000000  0.368098
# 1        0.15   0.247863  0.966667  0.394558
# 2        0.20   0.269231  0.933333  0.417910
# 3        0.25   0.301075  0.933333  0.455285
# 4        0.30   0.346154  0.900000  0.500000
# 5        0.35   0.400000  0.866667  0.547368
# 6        0.40   0.388889  0.700000  0.500000
# 7        0.45   0.285714  0.333333  0.307692
# 8        0.50   0.333333  0.266667  0.296296
# 9        0.55   0.153846  0.066667  0.093023
# 10       0.60   0.285714  0.066667  0.108108
# 11       0.65   0.500000  0.066667  0.117647
# 12       0.70   0.500000  0.033333  0.062500
# 13       0.75   0.000000  0.000000  0.000000
# 14       0.80   0.000000  0.000000  0.000000
# 15       0.85   0.000000  0.000000  0.000000
# 16       0.90   0.000000  0.000000  0.000000
#
# Best threshold based on F1:
# Threshold : 0.3500000000000001
# Precision : 0.4
# Recall    : 0.8666666666666667
# F1-score  : 0.5473684210526316
#
# Confusion Matrix:
# [[81 39]
#  [ 4 26]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Non-Melanoma     0.9529    0.6750    0.7902       120
#     Melanoma     0.4000    0.8667    0.5474        30
#
#     accuracy                         0.7133       150
#    macro avg     0.6765    0.7708    0.6688       150
# weighted avg     0.8424    0.7133    0.7417       150
# Validation ROC AUC: 0.7466666666666667
# Average Precision (AP): 0.3481152182623993
#
# All outputs saved in: /content/drive/MyDrive/isic_efficientnet_improved_output
